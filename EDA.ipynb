# %%
#import required libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %pip install seaborn

# %%
import seaborn as sns

# %%
#store the required data in a dataframe

# %%
df1=pd.read_csv("bank-additional-full.csv",sep=";",na_values="unknown")
#here we used na_values because the value 'unknown' is said to be null value in the description of the dataset

# %%
#output the first 5 rows of the dataset

# %%
df1.columns
df1.head()
# Out:
#    age        job  marital    education default housing loan    contact month  \
# 0   56  housemaid  married     basic.4y      no      no   no  telephone   may
# 1   57   services  married  high.school     NaN      no   no  telephone   may
# 2   37   services  married  high.school      no     yes   no  telephone   may
# 3   40     admin.  married     basic.6y      no      no   no  telephone   may
# 4   56   services  married  high.school      no      no  yes  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
# 3         mon  ...         1    999         0  nonexistent          1.1
# 4         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
#get the shape of the dataframe
df1.shape
# Out:
# (41188, 21)

# %%
#get the column names in the dataframe

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
#changing the column pdays with value 999 with null
df1.loc[df1['pdays'] == 999, 'pdays'] = 0

# %%
#get the datatypes of the columns
df1.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             40858 non-null  object
#  2   marital         41108 non-null  object
#  3   education       39457 non-null  object
#  4   default         32591 non-null  object
#  5   housing         40198 non-null  object
#  6   loan            40198 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593      0.221229      0.172963
# std       10.42125    259.279249      2.770014      1.348874      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000      0.000000      0.000000
# 50%       38.00000    180.000000      2.000000      0.000000      0.000000
# 75%       47.00000    319.000000      3.000000      0.000000      0.000000
# max       98.00000   4918.000000     56.000000     27.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
#change the name of the last column that is 'y'
df1.rename(columns={'y':'subscribed'},inplace=True)

# %%
#check the columns names after changing
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'subscribed'],
#       dtype='object')

# %%
#get unique values in each column of type object
for col in df1.select_dtypes(include='object').columns:
    print(col,":")
    print("   ",df1[col].unique())
    print()
# Out:
# job :
#     ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' nan 'entrepreneur' 'student']
#
# marital :
#     ['married' 'single' 'divorced' nan]
#
# education :
#     ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course' nan
#  'university.degree' 'illiterate']
#
# default :
#     ['no' nan 'yes']
#
# housing :
#     ['no' 'yes' nan]
#
# loan :
#     ['no' 'yes' nan]
#
# contact :
#     ['telephone' 'cellular']
#
# month :
#     ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
#
# day_of_week :
#     ['mon' 'tue' 'wed' 'thu' 'fri']
#
# poutcome :
#     ['nonexistent' 'failure' 'success']
#
# subscribed :
#     ['no' 'yes']

# %%
#from the above result you can find there are NaN(null) values the in the given dataset
df1.isnull().sum()
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# subscribed           0
# dtype: int64

# %%
df1=df1.dropna(axis=0)

# %%
#the above result shows that the indices are not proper
df1.reset_index(drop=True, inplace=True)

# %%
df1.head()
# Out:
#    age        job  marital            education default housing loan  \
# 0   56  housemaid  married             basic.4y      no      no   no
# 1   37   services  married          high.school      no     yes   no
# 2   40     admin.  married             basic.6y      no      no   no
# 3   56   services  married          high.school      no      no  yes
# 4   59     admin.  married  professional.course      no      no   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1      0         0  nonexistent
# 1  telephone   may         mon  ...         1      0         0  nonexistent
# 2  telephone   may         mon  ...         1      0         0  nonexistent
# 3  telephone   may         mon  ...         1      0         0  nonexistent
# 4  telephone   may         mon  ...         1      0         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# ...

# %%
#check if there are any null values after dropping null
df1.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# subscribed        0
# dtype: int64

# %%
#after dropping the null values the shape of the dataframe is:
df1.shape
# Out:
# (30488, 21)

# %%
#describe the dataset after dropping null values
df1.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  30488.000000  30488.000000  30488.000000  30488.000000  30488.000000
# mean      39.030012    259.484092      2.521451      0.257052      0.194273
# std       10.333529    261.714262      2.720150      1.448094      0.522788
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       31.000000    103.000000      1.000000      0.000000      0.000000
# 50%       37.000000    181.000000      2.000000      0.000000      0.000000
# 75%       45.000000    321.000000      3.000000      0.000000      0.000000
# max       95.000000   4918.000000     43.000000     27.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  30488.000000    30488.000000   30488.000000  30488.000000  30488.000000
# mean      -0.071510       93.523311     -40.602263      3.459938   5160.813409
# ...

# %%
#find unique values in each column of type object
for col in df1.select_dtypes(include='object').columns:
    print(col,":")
    print("   ",df1[col].unique())
    print()
# Out:
# job :
#     ['housemaid' 'services' 'admin.' 'technician' 'blue-collar' 'unemployed'
#  'retired' 'entrepreneur' 'management' 'student' 'self-employed']
#
# marital :
#     ['married' 'single' 'divorced']
#
# education :
#     ['basic.4y' 'high.school' 'basic.6y' 'professional.course' 'basic.9y'
#  'university.degree' 'illiterate']
#
# default :
#     ['no' 'yes']
#
# housing :
#     ['no' 'yes']
#
# loan :
#     ['no' 'yes']
#
# contact :
#     ['telephone' 'cellular']
#
# month :
#     ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
#
# day_of_week :
#     ['mon' 'tue' 'wed' 'thu' 'fri']
#
# poutcome :
#     ['nonexistent' 'failure' 'success']
#
# subscribed :
#     ['no' 'yes']

# %%
#getting all the categorical features in the dataset
categorical_features=[features for features in df1.columns if ((df1[features].dtypes=="O") & (features not in ['subscribed']))]
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
#finding the number of unique values of each categorical feature
for feature in categorical_features:
    print('The feature is {}, and the number of categories are {}'.format(feature,len(df1[feature].unique())))
# Out:
# The feature is job, and the number of categories are 11
# The feature is marital, and the number of categories are 3
# The feature is education, and the number of categories are 7
# The feature is default, and the number of categories are 2
# The feature is housing, and the number of categories are 2
# The feature is loan, and the number of categories are 2
# The feature is contact, and the number of categories are 2
# The feature is month, and the number of categories are 10
# The feature is day_of_week, and the number of categories are 5
# The feature is poutcome, and the number of categories are 3

# %%
#finding the counts of different categories present in each categorical variable
#representing the above graphs with values
for categorical_feature in categorical_features:
    print(categorical_feature,":")
    print()
    value_counts = df1[categorical_feature].value_counts()
    print(value_counts)
    print("\n\n\n")
# Out:
# job :
#
# admin.           8737
# blue-collar      5675
# technician       5473
# services         2857
# management       2311
# retired          1216
# self-employed    1092
# entrepreneur     1089
# unemployed        738
# housemaid         690
# student           610
# Name: job, dtype: int64
#
#
#
#
# marital :
#
# married     17492
# single       9443
# divorced     3553
# Name: marital, dtype: int64
#
#
#
#
# education :
#
# university.degree      10412
# high.school             7699
# professional.course     4321
# basic.9y                4276
# basic.4y                2380
# basic.6y                1389
# illiterate                11
# Name: education, dtype: int64
#
#
#
#
# default :
#
# no     30485
# yes        3
# Name: default, dtype: int64
#
#
#
#
# housing :
#
# yes    16521
# no     13967
# Name: housing, dtype: int64
#
#
#
#
# loan :
#
# no     25720
# yes     4768
# Name: loan, dtype: int64
#
#
#
#
# contact :
#
# cellular     20443
# telephone    10045
# ...

# %%
#finding the counts of different categories present in each categorical variable
#presenting graphically
plt.figure(figsize=(15,90), facecolor='white')
pltno=1
for categorical_feature in categorical_features:
    ax=plt.subplot(12,2,pltno)
    sns.countplot(y=categorical_feature,data=df1)
    plt.xlabel("categorical_feature")
    plt.title(categorical_feature)
    pltno+=1
plt.show()

# %%
#finding the counts of different categories present in each categorical variable grouped by subscription
#representing the above graphs with values
for categorical_feature in categorical_features:
    print(categorical_feature,":")
    value_counts = df1.groupby(["subscribed"])[categorical_feature].value_counts()
    print(value_counts,"\n")
    print("\n")
# Out:
# job :
# subscribed  job
# no          admin.           7521
#             blue-collar      5223
#             technician       4832
#             services         2599
#             management       2025
#             entrepreneur      988
#             self-employed     960
#             retired           859
#             unemployed        612
#             housemaid         603
#             student           407
# yes         admin.           1216
#             technician        641
#             blue-collar       452
#             retired           357
#             management        286
#             services          258
#             student           203
#             self-employed     132
#             unemployed        126
#             entrepreneur      101
#             housemaid          87
# Name: job, dtype: int64
#
#
#
# marital :
# subscribed  marital
# no          married     15436
#             single       8050
#             divorced     3143
# ...

# %%
#finding the counts of different categories present in each categorical variable grouped by subscription
#presenting using graphs
for categorical_feature in categorical_features:
    sns.catplot(x='subscribed', col=categorical_feature, kind='count', data=df1)
plt.show()

# %%
#finding the count of number of distinct values in the column subscribed
sns.countplot(x='subscribed', data=df1)
plt.show()sns.countplot(x="marital",hue="subscribed", data=df1)

# %%
sns.countplot(x="marital",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='count'>

# %%
#plotting the count of each distinct value present in the column job, categorized by subscribed column
plt.figure(figsize=(20,5))
sns.countplot(x="job",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='job', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="education",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.countplot(x="loan",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='loan', ylabel='count'>

# %%
sns.countplot(x="default",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
sns.countplot(x="housing",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='housing', ylabel='count'>

# %%
sns.countplot(x="contact",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='contact', ylabel='count'>

# %%
sns.countplot(x="poutcome",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='poutcome', ylabel='count'>

# %%
sns.countplot(x="month",hue="subscribed", data=df1)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
#numerical data in the dataset
numerical_features=[feature for feature in df1.columns if ((df1[feature].dtypes!="O") & (feature not in ['subscribed']))]
print('Number of numerical varibles :', len(numerical_features))
df1[numerical_features].head(10)
# Out:
# Number of numerical varibles : 10
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1      0         0           1.1          93.994
# 1   37       226         1      0         0           1.1          93.994
# 2   40       151         1      0         0           1.1          93.994
# 3   56       307         1      0         0           1.1          93.994
# 4   59       139         1      0         0           1.1          93.994
# 5   24       380         1      0         0           1.1          93.994
# 6   25        50         1      0         0           1.1          93.994
# 7   25       222         1      0         0           1.1          93.994
# 8   29       137         1      0         0           1.1          93.994
# 9   57       293         1      0         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -36.4      4.857       5191.0
# ...

# %%
#finding the discrete variables
discrete_feature=[feature for feature in numerical_features if len(df1[feature].unique())<25]
print("Discrete variables count:{}".format(len(discrete_feature)))
print(discrete_feature)
# Out:
# Discrete variables count:3
# ['previous', 'emp.var.rate', 'nr.employed']

# %%
#finding continuous features
continuous_features=[feature for feature in numerical_features if feature not in discrete_feature+['subscribed']]
print("Continuous feature count {}".format(len(continuous_features)))
print(continuous_features)
# Out:
# Continuous feature count 7
# ['age', 'duration', 'campaign', 'pdays', 'cons.price.idx', 'cons.conf.idx', 'euribor3m']

# %%
#plotting the distribution plot for each continuous features
plt.figure(figsize=(20,60))
plotno=1
for continuous_feature in continuous_features:
    ax=plt.subplot(12,2, plotno)
    sns.distplot(df1[continuous_feature], kde=False,bins=5)
    plt.xlabel(continuous_feature)
    plotno+=1
plt.show()
# Out:
# <ipython-input-49-8556bf50fa74>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[continuous_feature], kde=False,bins=5)

# %%
#plotting box plots for each continuous features and classified by the column subscribed
plt.figure(figsize=(20,90))
plotno=1
for feature in continuous_features:
    ax=plt.subplot(12,2, plotno)
    sns.boxplot(x="subscribed",y=df1[feature],data=df1)
    plt.title(feature)
    plotno+=1
plt.show()

# %%
df1['subscribed'] = df1['subscribed'].replace({'yes':1,'no':0})

# %%
corr_duration = df1['duration'].corr(df1['subscribed'])
corr_duration
# Out:
# 0.39353037689068343

# %%
corr_campaign = df1['campaign'].corr(df1['subscribed'])
corr_campaign
# Out:
# -0.06920562589015339

# %%
corr_pdays = df1['pdays'].corr(df1['subscribed'])
corr_pdays
# Out:
# 0.27024760336485704

# %%
corr_previous = df1['campaign'].corr(df1['subscribed'])
corr_previous
# Out:
# -0.06920562589015339

# %%
#plotting the heatmap for the dataset
cor_ma=df1.corr()
fig=plt.figure(figsize=(15,7))
sns.heatmap(cor_ma,annot=True)
# Out:
# <ipython-input-56-5d76ddc0cc3e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_ma=df1.corr()
# <AxesSubplot:>

# %%
sns.violinplot(x="subscribed",y="duration", data=df1)
# Out:
# <AxesSubplot:xlabel='subscribed', ylabel='duration'>

# %%
sns.violinplot(x="subscribed",y="campaign", data=df1)
# Out:
# <AxesSubplot:xlabel='subscribed', ylabel='campaign'>
